# %% [markdown]
# GENERAR IMAGEN CON 4 COLORES PRACTICA LUNES

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

plt.rcParams['figure.figsize']=[10,5]

tamanio_img=100
R = np.ones((tamanio_img, tamanio_img)) * 0
G = np.ones((tamanio_img, tamanio_img)) * 0
B = np.ones((tamanio_img, tamanio_img)) * 0

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype=int)

for i in range(50): 
    for j in range(50):
        imagen[i,j]=[255,0,0]

for i in range(50):
    for j in range(50):
        imagen[i,j+50]=[0,255,0]

for i in range(50):
    for j in range(50):
        imagen[i+50,j]=[0,0,255]

cv2.imwrite('img_4cuadrantes.jpg', imagen)

plt.figure()
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %%
import cv2 
import matplotlib as plt 

plt.rcParams['figure.figsize']=[10,5]
img=cv2.imread('img.jpg')
plt.inshow(img)
plt.show()
print('tamaño de imagen y canales: ',img.shape)

# %%
import cv2 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,5]
img=cv2.imread('profile.jpg',cv2.IMREAD_COLOR)

plt.subplot(141)
plt.title('imagen Original')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.imshow(img[:,:,0],cmap='gray')
plt.title('canal rojo')

plt.subplot(143)
plt.imshow(img[:,:,1],cmap='gray')
plt.title('canal verde')

plt.subplot(144)
plt.imshow(img[:,:,2],cmap='gray')
plt.title('canal canal azul')

plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize']=[10,5]
img=cv2.imread('profile.jpg',cv2.IMREAD_COLOR)
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

r=img[:,:,2]
g=img[:,:,1]
b=img[:,:,0]

r_imgen=np.zeros_like(img_rgb)
r_imgen[:,:,0]=r

g_imgen=np.zeros_like(img_rgb)
g_imgen[:,:,1]=g

b_imgen=np.zeros_like(img_rgb)
b_imgen[:,:,2]=b

plt.subplot(141)
plt.title('Original')
plt.imshow(img_rgb)
plt.axis('off')#para que no se muestre el alto y el ancho de la imagen 


plt.subplot(142)
plt.title('Canal Rojo')
plt.imshow(r_imgen)
plt.axis('off')

plt.subplot(143)
plt.title('Canal Verde')
plt.imshow(g_imgen)
plt.axis('off')

plt.subplot(144)
plt.title('Canal Azul')
plt.imshow(b_imgen)
plt.axis('off')


plt.show()

# %% [markdown]
# Colores Falsos

# %%
import cv2 
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize']=[10,5]
img=cv2.imread('profile.jpg',cv2.IMREAD_COLOR)
b,g,r=cv2.split(img)

plt.subplot(141)
plt.title('Original')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(142)
plt.title('Canal Rojo')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.imshow(r,cmap='Reds')
plt.axis('off')

plt.subplot(143)
plt.title('Canal Verde')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.imshow(g,cmap='Greens')
plt.axis('off')

plt.subplot(144)
plt.title('Canal Azul')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.imshow(b,cmap='Blues')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen en formato BGR y convertir a RGB
img_bgr = cv2.imread('profile.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Crear una figura con 4 subgráficos
fig, axs = plt.subplots(1, 4, figsize=(20, 5))

# Imagen original
axs[0].imshow(img_rgb)
axs[0].set_title('Original')
axs[0].axis('off')

# Canal Rojo
fig_img1 = axs[1].imshow(img_rgb[..., 0], cmap='gray')
fig.colorbar(fig_img1, ax=axs[1], shrink=0.5)
axs[1].set_title('Canal Rojo')

# Canal Verde
fig_img2 = axs[2].imshow(img_rgb[..., 1], cmap='gray')
fig.colorbar(fig_img2, ax=axs[2], shrink=0.5)
axs[2].set_title('Canal Verde')

# Canal Azul
fig_img3 = axs[3].imshow(img_rgb[..., 2], cmap='gray')
fig.colorbar(fig_img3, ax=axs[3], shrink=0.5)
axs[3].set_title('Canal Azul')

plt.show()

# %%
plt.imshow(img_rgb[:200,:2000,:])

# %%
cv2.imwrite('profile.jpg',img_bgr)
plt.imsave('img.jpg',cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB))

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np


plt.rcParams['figure.figsize']=[10,5]

img_size=100

R=np.ones((img_size,img_size))+255

G=np.ones((img_size,img_size))+128
B=np.ones((img_size,img_size))+10

P=np.ones((img_size,img_size))+10

imagen=np.dstack((R,G,B))

imagen=np.array(imagen,dtype=int)

plt.figure()
plt.imshow(imagen)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

data = np.random.rand(10,10) * 2 - 1



colors1 = plt.cm.binary(np.linspace(0., 1, 128))
colors2 = plt.cm.gist_heat_r(np.linspace(0, 1, 128))

colors = np.vstack((colors1, colors2))
mymap = mcolors.LinearSegmentedColormap.from_list('my_colormap', colors)

plt.pcolor(data, cmap=mymap)
plt.colorbar()
plt.show()

# %% [markdown]
# IMAGEN CON 4 CUADRANTES

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
import matplotlib.pyplot as plt
import numpy as np


img_size = 100


R = np.ones((img_size, img_size)) * 255 
G = np.ones((img_size, img_size)) * 128 
B = np.ones((img_size, img_size)) * 10   


imagen = np.dstack((R, G, B))


center_start = img_size // 3
center_end = 2 * img_size // 3

imagen[center_start:center_end, center_start:center_end] = [0, 0, 255]  

imagen = imagen.astype(int)

plt.figure(figsize=(5, 5))
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np


imagen = cv2.imread('profile.jpg', cv2.IMREAD_GRAYSCALE)

print('Profundidad de color original:', imagen.dtype)

img_16bit = (imagen.astype(np.uint16)) * 256  

print('Profundidad de color nueva:', img_16bit.dtype)


plt.rcParams['figure.figsize'] = [10, 5]

plt.subplot(121)
plt.title('Original (8-bit)')
plt.imshow(imagen, cmap='gray')
plt.axis('off')

plt.subplot(122)
plt.title('Convertida (16-bit)')
plt.imshow(img_16bit, cmap='gray')
plt.axis('off')
cv2.imwrite('profile_16bit.png', img_16bit)


plt.show()
# Out:
# Profundidad de color original: uint8
# Profundidad de color nueva: uint16

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

fig,axs=plt.subplots(1,4,figsize=(25,3))

img_bgr=cv2.imread('img.jpg')
img_rgb=cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)

hsv=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2HSV)

axs[0].imshow(img_rgb)

axs[0].set_title('imagen')

fig_img1=axs[1].imshow(hsv[...,0],cmap='gray',vmin=0,vmax=179)
fig.colorbar(fig_img1,ax=axs[1],shrink=0.3)
axs[1].set_title('canal H')

fig_img2=axs[2].imshow(hsv[...,0],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img2,ax=axs[2],shrink=0.3)
axs[2].set_title('canal S')

fig_img3=axs[3].imshow(hsv[...,0],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img3,ax=axs[3],shrink=0.3)
axs[3].set_title('canal V')
# Out:
# Text(0.5, 1.0, 'canal V')

# %%
import cv2 
import matplotlib.pyplot as plt  
import numpy as np 

# Leer la imagen y convertir de BGR a RGB
img_rgb = cv2.cvtColor(cv2.imread('img.jpg', cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)

# Convertir RGB a HSV
img_hsv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)

# Convertir HSV de nuevo a RGB
img_rgb2 = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2RGB)

# Crear la figura con 3 subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 10))  # Corregido figsize

# Mostrar imágenes
axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original (RGB)')

axs[1].imshow(img_hsv)
axs[1].set_title('RGB a HSV')

axs[2].imshow(img_rgb2)
axs[2].set_title('HSV a RGB')

# Ocultar ejes
for ax in axs:
    ax.axis('off')

# Mostrar la figura
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np


imagen = cv2.imread('img.jpg')

_,umbralBinario=cv2.threshold(imagen,127,255,cv2.THRESH_BINARY)

_,umbralBinariInverso=cv2.threshold(imagen,127,255,cv2.THRESH_BINARY_INV)

plt.subplot(1,3,1)
plt.imshow(imagen,cmap='gray')
plt.title('imagen orginal')

plt.subplot(1,3,2)
plt.imshow(umbralBinario,cmap='gray')
plt.title('imagen binaria umbralizada')


plt.subplot(1,3,3)
plt.imshow(umbralBinariInverso,cmap='gray')
plt.title('imagen binaria umbralizada')
# Out:
# Text(0.5, 1.0, 'imagen binaria umbralizada')

# %% [markdown]
# HSV 2 RGB

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np



Imagen = cv2.imread('img.jpg')
img= cv2.cvtColor(Imagen, cv2.COLOR_BGR2RGB)
def RGB2HSV(img):
    img = img.astype(np.float32)
    img = img/255.
    new_img = np.zeros_like(img)

    maxChannel = np.argmax(img,axis=2)
    maxValue = np.amax(img,axis=2)
    minChannel = np.argmin(img,axis=2)
    minValue = np.amin(img,axis=2)
    #value 
    new_img[...,2] = maxValue

    #saturation
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if maxValue[i,j]==0:
                new_img[i,j,1] = 0
            elif maxValue[i,j] != 0:
                new_img[i,j,1] = (new_img[i,j,2]-minValue[i,j])/new_img[i,j,2]

    #hue 
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if sum(img[i,j,...])/3 == img[i,j,0]:
                new_img[i,j,0] = 0
            elif maxChannel[i,j] == 0: #R 
                new_img[i,j,0] = 60 * ((img[i,j,1]-img[i,j,2])/(new_img[i,j,2]-minValue[i,j]))
            elif maxChannel[i,j] == 1: #G
                new_img[i,j,0] = 120 + 60 * (img[i,j,2]-img[i,j,0])/(new_img[i,j,2]-minValue[i,j])
            elif maxChannel[i,j] == 2: #B
                new_img[i,j,0] = 240 + 60 * (img[i,j,0]-img[i,j,1])/(new_img[i,j,2]-minValue[i,j])

        bol_ind = new_img[...,0] < 0
        new_img[bol_ind,0]   =  new_img[bol_ind,0] + 360
    return new_img 

hsv_img =  RGB2HSV(img) 
fig, axs = plt.subplots(1,4,figsize=(25,10))
axs[0].imshow(img)
axs[0].set_title('Imagen')
fig_img = axs[1].imshow(hsv_img[...,0],cmap='gray',vmin=0,vmax=360)
fig.colorbar(fig_img, ax=axs[1],shrink=0.3)
axs[1].set_title('Canal Hue')
fig_img = axs[2].imshow(hsv_img[...,1],cmap='gray',vmin=0,vmax=1)
fig.colorbar(fig_img, ax=axs[2],shrink=0.3)
axs[2].set_title('Canal Saturación')
fig_img = axs[3].imshow(hsv_img[...,2],cmap='gray',vmin=0,vmax=1)
fig.colorbar(fig_img, ax=axs[3],shrink=0.3)
axs[3].set_title('Canal Value');

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
def HSV2RGB(img):
    new_img = np.zeros_like(img)
    
    C = img[...,2]*img[...,1]
    X = C*(1-abs((img[...,0]/60)%2-1))
    m = img[...,2]-C

    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            h = img[i,j,0]
            if 0 <= h and h < 60:
                new_img[i,j] = C[i,j],X[i,j],0
            elif 60 <= h and h < 120:
                new_img[i,j] = X[i,j],C[i,j],0
            elif 120 <= h and h < 180:
                new_img[i,j] = 0,C[i,j],X[i,j]
            elif 180 <= h and h < 240:
                new_img[i,j] = 0,X[i,j],C[i,j]
            elif 240 <= h and h < 300:
                new_img[i,j] = X[i,j],0,C[i,j]
            elif 300 <= h and h < 360:
                new_img[i,j] = C[i,j],0,X[i,j]
    new_img[...,0] = (new_img[...,0]+m)*255
    new_img[...,1] = (new_img[...,1]+m)*255
    new_img[...,2] = (new_img[...,2]+m)*255
    new_img = new_img.astype(int)
    return new_img 
rgb_img =   HSV2RGB(hsv_img) 
fig, axs = plt.subplots(1,4,figsize=(25,10))

axs[0].imshow(img)
axs[0].set_title('Imagen')


fig_img = axs[1].imshow(rgb_img[...,0],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[1],shrink=0.3)
axs[1].set_title('Canal Rojo')


fig_img = axs[2].imshow(rgb_img[...,1],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[2],shrink=0.3)
axs[2].set_title('Canal Verde')


fig_img = axs[3].imshow(rgb_img[...,2],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[3],shrink=0.3)
axs[3].set_title('Canal Azul');
