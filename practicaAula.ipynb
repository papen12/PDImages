# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np


def convertirRGB(img, output_path="imagen_rgb.jpg"):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite(output_path, img_rgb)  
    plt.subplot(141)
    plt.title('BGR A RGB')
    plt.imshow(img_rgb)
    plt.show()

def escalaGrises(img, output_path="imagen_gris.jpg"):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, img_gray)  
    plt.subplot(141)
    plt.title('Escala de grises')
    plt.imshow(img_gray, cmap="gray")
    plt.show()



def chGrayEscale(img):
    plt.subplot(141)
    plt.title('imagen Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

    plt.subplot(142)
    plt.imshow(img[:,:,0],cmap='gray')
    plt.title('canal rojo')

    plt.subplot(143)
    plt.imshow(img[:,:,1],cmap='gray')
    plt.title('canal verde')

    plt.subplot(144)
    plt.imshow(img[:,:,2],cmap='gray')
    plt.title('canal canal azul')
    plt.show()

def ColorRGB(img):
    plt.rcParams['figure.figsize']=[10,5]
    img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

    r=img[:,:,2]
    g=img[:,:,1]
    b=img[:,:,0]

    r_imgen=np.zeros_like(img_rgb)
    r_imgen[:,:,0]=r

    g_imgen=np.zeros_like(img_rgb)
    g_imgen[:,:,1]=g

    b_imgen=np.zeros_like(img_rgb)
    b_imgen[:,:,2]=b

    plt.subplot(141)
    plt.title('Original')
    plt.imshow(img_rgb)
    plt.axis('off')

    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(r_imgen)
    plt.axis('off')

    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(g_imgen)
    plt.axis('off')

    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(b_imgen)
    plt.axis('off')

    plt.show()
def FkColor(img):
    plt.rcParams['figure.figsize']=[10,5]
    b,g,r=cv2.split(img)
    plt.subplot(141)
    plt.title('Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(r,cmap='Reds')
    plt.axis('off')
    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(g,cmap='Greens')
    plt.axis('off')
    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(b,cmap='Blues')
    plt.axis('off')

    plt.show()

img3 = cv2.imread('photos/photo3.jpg')
convertirRGB(img3)
escalaGrises(img3)
chGrayEscale(img3)
ColorRGB(img3)
FkColor(img3)

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np


def convertirRGB(img, output_path="imagen_rgb.jpg"):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite(output_path, img_rgb)  
    plt.subplot(141)
    plt.title('BGR A RGB')
    plt.imshow(img_rgb)
    plt.show()

def escalaGrises(img, output_path="imagen_gris.jpg"):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, img_gray)  
    plt.subplot(141)
    plt.title('Escala de grises')
    plt.imshow(img_gray, cmap="gray")
    plt.show()



def chGrayEscale(img):
    plt.subplot(141)
    plt.title('imagen Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

    plt.subplot(142)
    plt.imshow(img[:,:,0],cmap='gray')
    plt.title('canal rojo')

    plt.subplot(143)
    plt.imshow(img[:,:,1],cmap='gray')
    plt.title('canal verde')

    plt.subplot(144)
    plt.imshow(img[:,:,2],cmap='gray')
    plt.title('canal canal azul')
    plt.show()

def ColorRGB(img):
    plt.rcParams['figure.figsize']=[10,5]
    img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

    r=img[:,:,2]
    g=img[:,:,1]
    b=img[:,:,0]

    r_imgen=np.zeros_like(img_rgb)
    r_imgen[:,:,0]=r

    g_imgen=np.zeros_like(img_rgb)
    g_imgen[:,:,1]=g

    b_imgen=np.zeros_like(img_rgb)
    b_imgen[:,:,2]=b

    plt.subplot(141)
    plt.title('Original')
    plt.imshow(img_rgb)
    plt.axis('off')

    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(r_imgen)
    plt.axis('off')

    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(g_imgen)
    plt.axis('off')

    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(b_imgen)
    plt.axis('off')

    plt.show()
def FkColor(img):
    plt.rcParams['figure.figsize']=[10,5]
    b,g,r=cv2.split(img)
    plt.subplot(141)
    plt.title('Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(r,cmap='Reds')
    plt.axis('off')
    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(g,cmap='Greens')
    plt.axis('off')
    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(b,cmap='Blues')
    plt.axis('off')

    plt.show()

img2 = cv2.imread('photos/photo1.jpg')
convertirRGB(img2)
escalaGrises(img2)
chGrayEscale(img2)
ColorRGB(img2)
FkColor(img2)

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
def convertirRGB(img, output_path="imagen_rgb.jpg"):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite(output_path, img_rgb)  
    plt.subplot(141)
    plt.title('BGR A RGB')
    plt.imshow(img_rgb)
    plt.show()

def escalaGrises(img, output_path="imagen_gris.jpg"):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, img_gray)  
    plt.subplot(141)
    plt.title('Escala de grises')
    plt.imshow(img_gray, cmap="gray")
    plt.show()


def chGrayEscale(img):
    plt.subplot(141)
    plt.title('imagen Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

    plt.subplot(142)
    plt.imshow(img[:,:,0],cmap='gray')
    plt.title('canal rojo')

    plt.subplot(143)
    plt.imshow(img[:,:,1],cmap='gray')
    plt.title('canal verde')

    plt.subplot(144)
    plt.imshow(img[:,:,2],cmap='gray')
    plt.title('canal canal azul')
    plt.show()

def ColorRGB(img):
    plt.rcParams['figure.figsize']=[10,5]
    img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

    r=img[:,:,2]
    g=img[:,:,1]
    b=img[:,:,0]

    r_imgen=np.zeros_like(img_rgb)
    r_imgen[:,:,0]=r

    g_imgen=np.zeros_like(img_rgb)
    g_imgen[:,:,1]=g

    b_imgen=np.zeros_like(img_rgb)
    b_imgen[:,:,2]=b

    plt.subplot(141)
    plt.title('Original')
    plt.imshow(img_rgb)
    plt.axis('off')

    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(r_imgen)
    plt.axis('off')

    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(g_imgen)
    plt.axis('off')

    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(b_imgen)
    plt.axis('off')

    plt.show()
def FkColor(img):
    plt.rcParams['figure.figsize']=[10,5]
    b,g,r=cv2.split(img)
    plt.subplot(141)
    plt.title('Original')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.subplot(142)
    plt.title('Canal Rojo')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(r,cmap='Reds')
    plt.axis('off')
    plt.subplot(143)
    plt.title('Canal Verde')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(g,cmap='Greens')
    plt.axis('off')
    plt.subplot(144)
    plt.title('Canal Azul')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.imshow(b,cmap='Blues')
    plt.axis('off')

    plt.show()

img2 = cv2.imread('photos/photo2.jpg')
convertirRGB(img2)
escalaGrises(img2)
chGrayEscale(img2)
ColorRGB(img2)
FkColor(img2)
